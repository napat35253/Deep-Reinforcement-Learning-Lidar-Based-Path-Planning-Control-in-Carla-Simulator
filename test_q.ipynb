# %%
import pandas as pd
import numpy as np
from plotnine import *

# %%
df=pd.read_csv('train_data_1.csv')

# %%
ggplot(df, aes(x='Reward')) + \
   geom_density(color="#48b6a3")
# Out:
# <ggplot: (134255027660)>

# %%
ggplot(df, aes(x='Episode', y='Reward')) + \
    geom_line(color='steelblue')
# Out:
# <ggplot: (-9223371902598458915)>

# %%
df['Reward' > 12 ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-be98de1ebb35> in <module>
# ----> 1 df['Reward' > 12 ]
#
# TypeError: '>' not supported between instances of 'str' and 'int'
